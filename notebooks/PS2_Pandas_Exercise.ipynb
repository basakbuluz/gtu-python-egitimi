# %% [markdown]
# Bu egzersizde, bu hafta ele aldığımız Pandas ve NumPy kütüphanelerindeki bazı kavram ve becerileri uygulayacaksınız.
#
# Bu not defterini gözden geçirirken, bazı yerlerde boş hücreler bulacaksınız. Bu egzersizi tamamlamak için, not defterinin uçtan uca düzgün çalışmasını sağlamak üzere tüm boş hücreleri uygun değerler, ifadeler veya deyimlerle tamamlamanız gerektiğini unutmayın.
#
# **Akılda tutulması gereken bazı şeyler:**
#
# Tüm kod hücrelerini çalıştırdığınızdan emin olun, aksi takdirde tanımlanmamış değişkenler için NameError gibi hatalar alabilirsiniz.
#
# Değişken adlarını değiştirmeyin, hücreleri silmeyin veya mevcut diğer kodları bozmayın.
#
#
# PS süresince online toplantıda aktif olarak bulunan tutor hocalarımızdan hatalarla ilgili yardım alabilir veya ipuçları isteyebilirsiniz.

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# Bu egzersizde, bir CSV dosyasındaki veriler üzerinde bir analiz gerçekleştireceksiniz. CSV dosyasını indirerek başlayalım.

# %%
countries_df = pd.read_csv('https://raw.githubusercontent.com/basakbuluz/gtu-python-egitimi/main/notebooks/datasets/locations.csv')

countries_df.head()
# Out:
#       location continent  population  life_expectancy  \
# 0  Afghanistan      Asia  38928341.0            64.83
# 1      Albania    Europe   2877800.0            78.57
# 2      Algeria    Africa  43851043.0            76.88
# 3      Andorra    Europe     77265.0            83.73
# 4       Angola    Africa  32866268.0            61.15
#
#    hospital_beds_per_thousand  gdp_per_capita
# 0                        0.50        1803.987
# 1                        2.89       11803.431
# 2                        1.90       13913.839
# 3                         NaN             NaN
# 4                         NaN        5819.495

# %% [markdown]
# **Veri kümesi kaç ülke içeriyor?**
#
# İpucu: .shape yöntemini kullanın.

# %%
# . shape kullanarak ülke sayısını hesaplatınız ve num_countries değişkenine o değeri atayınız.


print('Veri kümesinde yer alan ülke sayısı {} dır.'.format(num_countries))
# Out:
# Veri kümesinde yer alan ülke sayısı 212 dır.

# %% [markdown]
# **Veri kümesi içerisinde geçen kıtaların bir listesini yazdırın.**
#
# İpucu: .unique yöntemini kullanın.

# %%
# .unique kullanarak kıta sayısını hesaplatınız ve unique_continents değişkenine o değeri atayınız.

# %%
print('Veri kümesinde yer alan kıtalar:',unique_continents)
# Out:
# Veri kümesinde yer alan kıtalar: ['Asia' 'Europe' 'Africa' 'North America' 'South America' 'Oceania' nan]

# %% [markdown]
# **Bu veri kümesinde listelenen tüm ülkelerin toplam nüfusunu yazdırınız.**

# %%
# .sum kullanarak tüm ülkelerin toplam nüfusunu hesaplatınız ve total_population değişkenine o değeri atayınız.


print('Tüm ülkelerin toplam nüfusu: {}.'.format(int(total_population)))
# Out:
# Tüm ülkelerin toplam nüfusu: 15552778824.

# %% [markdown]
# **En yüksek nüfusa sahip 10 ülkeyi içeren bir dataframe oluşturun.**
#
# İpucu: sort_values ve head yöntemlerini zincirleme kullanınız.

# %%
# Azalan sırada nüfusa göre sırala ve head(10) ile ilk 10 ülkeyi al


# Dataframe'i ekrana yazdır.
most_populous_df
# Out:
#           location      continent    population  life_expectancy  \
# 210          World            NaN  7.794799e+09            72.58
# 41           China           Asia  1.439324e+09            76.91
# 90           India           Asia  1.380004e+09            69.66
# 199  United States  North America  3.310026e+08            78.86
# 91       Indonesia           Asia  2.735236e+08            71.72
# 145       Pakistan           Asia  2.208923e+08            67.27
# 27          Brazil  South America  2.125594e+08            75.88
# 141        Nigeria         Africa  2.061396e+08            54.69
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 157         Russia         Europe  1.459345e+08            72.58
#
#      hospital_beds_per_thousand  gdp_per_capita
# 210                       2.705       15469.207
# 41                        4.340       15308.712
# 90                        0.530        6426.674
# 199                       2.770       54225.446
# ...

# %% [markdown]
# **Ülke başına toplam GSYİH (GDP)'yi (nüfus ve kişi başına GSYİH çarpımı) kaydetmek için countries_df'ye yeni bir sütun ekleyin.**

# %%
#  Ülke başına toplam GSYİH (GDP)'yi hesaplayın


# Dataframe'i yeni sütunla birlikte yazdır
print(countries_df)
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 0                         0.500        1803.987  7.022622e+10
# 1                         2.890       11803.431  3.396791e+10
# ...

# %% [markdown]
# **Nüfusu 100 milyondan fazla olan ülkeler arasında kişi başına en düşük GSYİH'ye sahip 10 ülkeyi içeren bir dataframe oluşturun.**

# %%
# Nüfusu 100 milyondan fazla olan ülkeleri filtreleyin
filtered_df =

# Kişi başına düşen GSYİH'ye göre artan sırada sıralayın
sorted_df =

# Kişi başına düşen GSYİH en düşük olan 10 ülkeyi alın
lowest_gdp_df = sorted_df.head(10)

# Print the dataframe
print(lowest_gdp_df)
# Out:
#         location      continent    population  life_expectancy  \
# 63      Ethiopia         Africa  1.149636e+08            66.60
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 145     Pakistan           Asia  2.208923e+08            67.27
# 141      Nigeria         Africa  2.061396e+08            54.69
# 90         India           Asia  1.380004e+09            69.66
# 151  Philippines           Asia  1.095811e+08            71.23
# 58         Egypt         Africa  1.023344e+08            71.99
# 91     Indonesia           Asia  2.735236e+08            71.72
# 27        Brazil  South America  2.125594e+08            75.88
# 41         China           Asia  1.439324e+09            76.91
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 63                         0.30        1729.927  1.988786e+11
# 15                         0.80        3523.984  5.803628e+11
# 145                        0.60        5034.708  1.112128e+12
# ...

# %% [markdown]
# **Her kıtadaki ülke sayısını sayan bir dataframe oluşturun.**
#
# İpucu: groupby kullanın, location sütununu seçin ve count kullanarak toplayın.

# %%
# Kıtalara göre gruplayın ve ülke sayısını sayın
continent_counts_df =

# Dataframe'i ekrana yazdırın
print(continent_counts_df)
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: location, dtype: int64

# %% [markdown]
# **Her kıtanın toplam nüfusunu gösteren bir data frame oluşturun.**
#
# İpucu: groupby kullanın, population sütununu seçin ve sum kullanarak toplayın.

# %%
# Kıtalara göre gruplandırın ve nüfusu toplayın
continent_populations_df =

# Dataframe'i ekrana yazdırın
print(continent_populations_df)
# Out:
# continent
# Africa           1.339424e+09
# Asia             4.607388e+09
# Europe           7.485062e+08
# North America    5.912425e+08
# Oceania          4.095832e+07
# South America    4.304611e+08
# Name: population, dtype: float64

# %% [markdown]
# **Çeşitli ülkeler için genel Covid-19 istatistiklerini içeren başka bir CSV dosyası indirelim ve verileri başka bir Pandas dataframe ile okuyalım.**

# %%
covid_data_df = pd.read_csv('https://raw.githubusercontent.com/basakbuluz/gtu-python-egitimi/main/notebooks/datasets/covid-countries-data.csv')
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# **total_tests verisinin eksik olduğu ülke sayısını sayın.**
#
# İpucu: .isna yöntemini kullanın.

# %%
# total_tests içindeki eksik değerlerin sayısını .isna kullanarak sayın
total_tests_missing =

# Eksik değerlerin sayısını yazdır
print(" Total test verisi eksik olan ülke sayısı: {} .".format(int(total_tests_missing)))
# Out:
# The data for total tests is missing for 122 countries.

# %% [markdown]
# İki dataframei birleştirelim ve bazı ölçümleri daha hesaplayalım.
#
# **countries_df ile covid_data_df yi location sütununda birleştirin.**
#
# *İpucu: countries_df üzerinde .merge yöntemini kullanın.

# %%
# Dataframe'leri "location" sütununda birleştirin
combined_df =

# Birleştirilmiş dataframe'i ekrana yazdırın.
print(combined_df)
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                         0.500        1803.987  7.022622e+10      38243.0
# 1                         2.890       11803.431  3.396791e+10       9728.0
# ...

# %% [markdown]
# **combined_df içine tests_per_million, cases_per_million ve deaths_per_million sütunlarını ekleyin.**

# %%
# Yeni sütunları hesaplayın.

combined_df["tests_per_million"] = combined_df["total_tests"]* 1e6 / combined_df["population"]
combined_df["cases_per_million"] =
combined_df["deaths_per_million"] =

print(combined_df)
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                         0.500        1803.987  7.022622e+10      38243.0
# 1                         2.890       11803.431  3.396791e+10       9728.0
# ...

# %% [markdown]
# **Milyon kişi başına en yüksek test sayısına sahip 10 ülkeyi içeren bir dataframe oluşturun.**

# %%
highest_tests_df = combined_df.sort_values("tests_per_million",ascending=False).head(10).reset_index()

highest_tests_df
# Out:
#    index              location      continent   population  life_expectancy  \
# 0    197  United Arab Emirates           Asia    9890400.0            77.97
# 1     14               Bahrain           Asia    1701583.0            77.29
# 2    115            Luxembourg         Europe     625976.0            82.25
# 3    122                 Malta         Europe     441539.0            82.53
# 4     53               Denmark         Europe    5792203.0            80.90
# 5     96                Israel           Asia    8655541.0            82.97
# 6     89               Iceland         Europe     341250.0            82.99
# 7    157                Russia         Europe  145934460.0            72.58
# 8    199         United States  North America  331002647.0            78.86
# 9     10             Australia        Oceania   25499881.0            83.44
#
#    hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# ...

# %% [markdown]
# **Milyon kişi başına en yüksek pozitif vaka sayısına sahip 10 ülkeyi içeren bir dataframe oluşturun.**

# %%
highest_cases_df =
highest_cases_df
# Out:
#    index       location      continent   population  life_expectancy  \
# 0    155          Qatar           Asia    2881060.0            80.23
# 1     14        Bahrain           Asia    1701583.0            77.29
# 2    147         Panama  North America    4314768.0            78.51
# 3     40          Chile  South America   19116209.0            80.18
# 4    162     San Marino         Europe      33938.0            84.97
# 5      9          Aruba  North America     106766.0            76.29
# 6    105         Kuwait           Asia    4270563.0            75.49
# 7    150           Peru  South America   32971846.0            76.74
# 8     27         Brazil  South America  212559409.0            75.88
# 9    199  United States  North America  331002647.0            78.86
#
#    hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                        1.20      116935.600  3.368985e+11     119206.0
# ...

# %% [markdown]
# **Milyon kişi başına en yüksek ölüm vakası sayısına sahip 10 ülkeyi içeren bir dataframe oluşturunuz.**

# %%
highest_deaths_df =
highest_deaths_df
# Out:
#    index        location      continent   population  life_expectancy  \
# 0    162      San Marino         Europe      33938.0            84.97
# 1    150            Peru  South America   32971846.0            76.74
# 2     18         Belgium         Europe   11589616.0            81.63
# 3      3         Andorra         Europe      77265.0            83.73
# 4    177           Spain         Europe   46754783.0            83.56
# 5    198  United Kingdom         Europe   67886004.0            81.32
# 6     40           Chile  South America   19116209.0            80.18
# 7     97           Italy         Europe   60461828.0            83.51
# 8     27          Brazil  South America  212559409.0            75.88
# 9    182          Sweden         Europe   10099270.0            82.80
#
#    hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                        3.80       56861.470  1.929765e+09        735.0
# ...

# %% [markdown]
# **Hem "milyon başına en yüksek test sayısı" hem de "milyon başına en yüksek vaka sayısı" listelerinde yer alan ülkelerin sayısını sayın.**

# %%
highest_test_and_cases =

print(f"Hem vaka sayısı hem de Covid test sayısı en yüksek olan toplam ülke sayısı: {highest_test_and_cases}")
# Out:
# Total number of Contries having both highest number of cases and covid tests are: 2

# %% [markdown]
# **"Kişi başına en düşük GSYİH'ye sahip 20 ülke" ve "bin nüfus başına en düşük hastane yatağı sayısına sahip 20 ülke" listelerinin her ikisinde de yer alan ülke sayısını sayın. Listeyi oluştururken sadece nüfusu 10 milyondan fazla olan ülkeleri dikkate alın.**

# %%
lowest_gdp_df =
lowest_gdp_df
# Out:
#     index                      location      continent   population  \
# 0      32                       Burundi         Africa   11890781.0
# 1      52  Democratic Republic of Congo         Africa   89561404.0
# 2     140                         Niger         Africa   24206636.0
# 3     118                        Malawi         Africa   19129955.0
# 4     132                    Mozambique         Africa   31255435.0
# 5     117                    Madagascar         Africa   27691019.0
# 6     207                         Yemen           Asia   29825968.0
# 7     176                   South Sudan         Africa   11193729.0
# 8      85                         Haiti  North America   11402533.0
# 9     195                        Uganda         Africa   45741000.0
# 10     31                  Burkina Faso         Africa   20903278.0
# 11     63                      Ethiopia         Africa  114963583.0
# 12     39                          Chad         Africa   16425859.0
# ...

# %%
lowest_hospital_df =
lowest_hospital_df
# Out:
#     index      location      continent    population  life_expectancy  \
# 0     121          Mali         Africa  2.025083e+07            59.31
# 1     117    Madagascar         Africa  2.769102e+07            67.04
# 2     140         Niger         Africa  2.420664e+07            62.42
# 3     135         Nepal           Asia  2.913681e+07            70.78
# 4      82        Guinea         Africa  1.313279e+07            61.60
# 5      63      Ethiopia         Africa  1.149636e+08            66.60
# 6      31  Burkina Faso         Africa  2.090328e+07            61.58
# 7     195        Uganda         Africa  4.574100e+07            63.37
# 8       0   Afghanistan           Asia  3.892834e+07            64.83
# 9      20         Benin         Africa  1.212320e+07            61.77
# 10     90         India           Asia  1.380004e+09            69.66
# 11     80     Guatemala  North America  1.791557e+07            74.30
# ...

# %%
total_countries_having_low_gdp_and_bed =
print(f"Kişi başına en düşük GSYİH ve en düşük hastane yatağına sahip ülke sayısı {total_countries_having_low_gdp_and_bed}")
# Out:
# Kişi başına en düşük GSYİH ve en düşük hastane yatağına sahip ülke sayısı 14
